# %% [markdown]
# # DATA CLEANING ON AIRBNB DATASET

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
bnb=pd.read_csv("Airbnb_Open_Data.csv",low_memory=False,dtype={25: str})
bnb.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
bnb.shape
# Out:
# (102599, 26)

# %%
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
bnb["license"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 102594    NaN
# 102595    NaN
# 102596    NaN
# 102597    NaN
# 102598    NaN
# Name: license, Length: 102599, dtype: object

# %%
bnb.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %% [markdown]
# #### 1.DELETING DATA REDUNDANT COLUMN

# %%
columns_to_keep=['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop=['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules','id']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 6

# %% [markdown]
# ### 1st METHOD FILTERING DATA

# %%
data=bnb[columns_to_keep]
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
data.shape
# Out:
# (102599, 19)

# %% [markdown]
# ### 2nd METHOD DROPPING COLUMNS

# %%
bnb.drop(columns=columns_to_drop,inplace=True)

# %%
bnb
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
bnb.shape
# Out:
# (102599, 19)

# %% [markdown]
# ### RENAMING COLUMNS

# %%
bnb.rename(columns={"NAME":"Name"},inplace=True)

# %%
bnb
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
new_column_names=[]
for i in bnb.columns:
    new_column_names.append(i.upper())

# %%
new_column_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
data_frame_to_modify=bnb.copy()

# %%
data_frame_to_modify
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
 data_frame_to_modify.columns=new_column_names

# %%
 data_frame_to_modify
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %%
 data_frame_to_modify.duplicated().sum()
# Out:
# 541

# %%
 data_frame_to_modify.drop_duplicates(inplace=True)

# %%
 data_frame_to_modify.duplicated().sum()
# Out:
# 0

# %%
 data_frame_to_modify
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
 data_frame_to_modify.isna().sum()
# Out:
# NAME                        250
# HOST ID                       0
# HOST_IDENTITY_VERIFIED      289
# HOST NAME                   404
# NEIGHBOURHOOD GROUP          29
# NEIGHBOURHOOD                16
# LAT                           8
# LONG                          8
# COUNTRY                     532
# COUNTRY CODE                131
# INSTANT_BOOKABLE            105
# CANCELLATION_POLICY          76
# ROOM TYPE                     0
# CONSTRUCTION YEAR           214
# PRICE                       247
# SERVICE FEE                 273
# MINIMUM NIGHTS              400
# NUMBER OF REVIEWS           183
# LAST REVIEW               15832
# dtype: int64

# %%
dataframe= data_frame_to_modify.copy()

# %%
dataframe
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %% [markdown]
# #### REMOVING NULL VALUES IN THE COLUMN

# %%
 dataframe.drop(columns=['LAST REVIEW'],inplace=True)

# %%
dataframe.isna().sum()
# Out:
# NAME                      250
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    289
# HOST NAME                 404
# NEIGHBOURHOOD GROUP        29
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   532
# COUNTRY CODE              131
# INSTANT_BOOKABLE          105
# CANCELLATION_POLICY        76
# ROOM TYPE                   0
# CONSTRUCTION YEAR         214
# PRICE                     247
# SERVICE FEE               273
# MINIMUM NIGHTS            400
# NUMBER OF REVIEWS         183
# dtype: int64

# %%
 dataframe.dropna(inplace=True)

# %%
dataframe.isna().sum()
# Out:
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# dtype: int64

# %% [markdown]
# #### CLEANING INDIVIDUAL COLUMNS

# %%
 dataframe
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
 dataframe["HOST_IDENTITY_VERIFIED"]
# Out:
# 0         unconfirmed
# 1            verified
# 4            verified
# 5            verified
# 7         unconfirmed
#              ...
# 102029    unconfirmed
# 102030       verified
# 102031       verified
# 102032    unconfirmed
# 102040       verified
# Name: HOST_IDENTITY_VERIFIED, Length: 99342, dtype: object

# %%
 dataframe["HOST_IDENTITY_VERIFIED"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: HOST_IDENTITY_VERIFIED, Length: 99342, dtype: object

# %%
 dataframe["HOST_IDENTITY_VERIFIED"]= dataframe["HOST_IDENTITY_VERIFIED"].str.upper()

# %%
 dataframe
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
dataframe["INSTANT_BOOKABLE"].apply(lambda x: 1 if x== True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: INSTANT_BOOKABLE, Length: 99342, dtype: int64

# %%
dataframe["INSTANT_BOOKABLE"]=dataframe["INSTANT_BOOKABLE"].apply(lambda x: 1 if x== True else 0)

# %%
dataframe
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
dataframe.reset_index(inplace=True)

# %%
dataframe
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
type(dataframe["PRICE"][15])
# Out:
# str

# %%
dataframe["PRICE"]=dataframe["PRICE"].str.replace("$","")

# %%
dataframe["PRICE"]
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: PRICE, Length: 99342, dtype: object

# %%
dataframe["PRICE"]=dataframe["PRICE"].str.replace(",","")

# %%
dataframe["PRICE"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: object

# %%
dataframe["PRICE"][15]
# Out:
# '1020 '

# %%
dataframe["PRICE"]=dataframe["PRICE"].str.replace(" ","")

# %%
dataframe["PRICE"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: object

# %%
type(dataframe["PRICE"][1])
# Out:
# str

# %%
dataframe["PRICE"].astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: int32

# %%
dataframe["PRICE"]=dataframe["PRICE"].astype(int)

# %%
dataframe["PRICE"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: int32

# %%
dataframe
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
dataframe.to_csv("Cleaned_dataset_of_AIRBNB")

# %%
pd.read_csv("Cleaned_dataset_of_AIRBNB")
# Out:
#        Unnamed: 0   index                                              NAME  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 99337       99337  102029            Cozy room in a 2B with backyard access
# 99338       99338  102030                      An East Williamsburg Delight
# 99339       99339  102031                      Cozy bedroom in williamsburg
# 99340       99340  102032                            Spacious Room w/ 2 Bed
# 99341       99341  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
dataframe.to_csv("Cleaned_dataset_of_AIRBNB",index=False)

# %%
pd.read_csv("Cleaned_dataset_of_AIRBNB")
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
dataframe.drop(columns="index",inplace=True)

# %%
dataframe
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
dataframe.to_excel("EXCEL Cleaned_dataset_of_AIRBNB.xlsx",index=False)

# %%
dataframe.to_csv("CSV Cleaned_dataset_of_AIRBNB.csv",index=False)

# %%
dataframe
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
pd.read_excel("Excel Cleaned_dataset_of_AIRBNB.xlsx")
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
pd.read_csv("CSV Cleaned_dataset_of_AIRBNB.csv")
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...
